# %% [markdown]
# ### Задание 1

# %% [markdown]
# Монетку подбрасывают 15 раз, найдите вероятность выпадения простого числа орлов (решение на бумажке и на python).

# %% [markdown]
# Простое число - число, имеющее в делителях 1 и само себя. Простые числа до 15: 2, 3, 5, 7, 11, 13.

# %%
from PIL import Image

# %%
img = Image.open("coin_task.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1024x834 at 0x7F81602C7880>

# %%
# моделирование игры
# 1 - решка
# 0 - орел

import numpy as np

trials = 1000000    # Количество попыток
nit = 15          # Количество бросков монеты за одну попытку
count = 0 
win = 0

for i in range(trials):
    for k in range(nit):
        random_score = np.random.randint(0, 2)
        if random_score == 0:
            count += 1
    if count in [2, 3, 5, 7, 11, 13]:
        win += 1
    count = 0
    
        
print(win/trials)
# Out:
# 0.34943

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Создайте свою дискретную случайную величину с не менее, чем 10 значениями. Просемплируйте 1000 случайных значений, постройте гистограмму плотности распределения по выборке, посчитайте среднее, дисперсию и медиану.

# %%
import matplotlib.pyplot as plt
import seaborn
import numpy as np
import random
import scipy.stats as sps

# %%
data=binom.rvs(n=10,p=0.5,loc=0,size=1000)

print(f'среднее значение {data.mean():.2f}; дисперсия {data.var():.2f}, медиана {n*p}')
# Out:
# среднее значение 5.03; дисперсия 2.46, медиана 5.0

# %%
data=binom.rvs(n=10,p=0.5,loc=0,size=1000)
ax=seaborn.distplot(data,
                kde=True,
                color='pink',
                hist_kws={"linewidth": 22,'alpha':0.77})
ax.set(xlabel='Binomial',ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Binomial')]

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Пусть брошены 3 уравновешенные монеты. Рассмотрим 3 события:
#
# $A_1$ - монеты 1 и 2 упали одной и той же стороной,
#
# $A_2$ - монеты 2 и 3 упали одной и той же стороной,
#
# $A_3$ - монеты 1 и 3 упали одной и той же стороной.
#
# Покажите, почему эти 3 события являются попарно независимыми, но <b>не</b> являются независимыми в совокупности.

# %% [markdown]
# Возможные варианты падения монет (разницы между броском трех монет и тремя бросаниями одной монеты нет): ООО, PPP, OPO, OOP, POO, POP, PPO, POO.
# - P(A1) = 4/8 = 1/2
# - P(A2) = 1/2
# - P(A3) = 1/2
#
# Вероятность совокупности независимых событий равна 1. Если же просуммировать вероятность всех трех событий, то получается 1.5, что означает зависимость событий.

# %% [markdown]
# ### Задание 4 (формула полной вероятности)

# %% [markdown]
# В магазин привезли устройства с 3-х разных предприятий. Соотношение устройств следующее: 20% - продукция первого предприятия, 30% - продукция второго предприятия, 50% - продукция третьего предприятия; далее, 10% продукции первого предприятия высшего сорта, на втором предприятии - 5% и на третьем - 20% продукции высшего сорта. Найти вероятность того, что случайно купленная новая продукция окажется высшего сорта.

# %% [markdown]
# A1 - продукция первого предприятия Р(А1) = 0,2
#
# A2 - продукция второго предприятия Р(А2) = 0,3
#
# A3 - продукция третьего предприятия Р(А3) = 0,5
#
# B - продукция высшего сорта
#
# Р(B)-?
#
# $Р(B) = Р(А1|В) + Р(А2|В) + Р(А3|В) = 0,2*0,1 + 0,3*0,05 + 0,5 *0,2 = 0,02 + 0,015 + 0,1 = 0,135 = 13,5$
